# %% [markdown]
# # Weekly Project 2!

# %% [markdown]
# ## Introduction to Road Traffic Accidents (RTA) Dataset
#
# ### Dataset Overview
# The RTA Dataset provides a detailed snapshot of road traffic accidents, capturing a range of data from accident conditions to casualty details. This dataset is essential for analyzing patterns and causes of accidents to improve road safety.
#
# ### Data Characteristics
# - **Entries**: The dataset contains 12,316 entries.
# - **Features**: There are 32 features in the dataset, which include:
#   - `Time`: Time when the accident occurred.
#   - `Day_of_week`: Day of the week.
#   - `Age_band_of_driver`: Age group of the driver involved.
#   - `Sex_of_driver`: Gender of the driver.
#   - `Educational_level`: Educational level of the driver.
#   - `Type_of_vehicle`: Type of vehicle involved in the accident.
#   - `Cause_of_accident`: Reported cause of the accident.
#   - `Accident_severity`: Severity of the accident.
# - **Target Column**: `Accident_severity` is used as the target column for modeling. This feature classifies the severity of each accident.
#
# ### Objective
# Students will use this dataset to apply various data visualization, modeling, and evaluation techniques learned in class. The primary goal is to build models that can accurately predict the severity of accidents and to identify the key factors that contribute to severe accidents.

# %% [markdown]
# ## Import Libraries
# Import all the necessary libraries here. Include libraries for handling data (like pandas), visualization (like matplotlib and seaborn), and modeling (like scikit-learn).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data
# Load the dataset from the provided CSV file into a DataFrame.

# %%
df = pd.read_csv('/content/Datasets/RTA_Dataset.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Perform EDA to understand the data better. This involves several steps to summarize the main characteristics, uncover patterns, and establish relationships:
# * Find the dataset information and observe the datatypes.
# * Check the shape of the data to understand its structure.
# * View the the data with various functions to get an initial sense of the data.
# * Perform summary statistics on the dataset to grasp central tendencies and variability.
# * Check for duplicated data.
# * Check for null values.
#
# And apply more if needed!

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample(6)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 3141   13:30:00      Friday            Unknown          Male
# 12022  19:47:00    Saturday              18-30          Male
# 1277    7:22:00    Thursday              18-30       Unknown
# 6649    8:15:00      Monday              18-30          Male
# 5817   18:00:00    Saturday              18-30          Male
# 319    20:30:00      Sunday            Over 51          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 3141    Elementary school                Employee          Below 1yr
# 12022  Junior high school                   Owner         Above 10yr
# 1277   Junior high school                Employee          Below 1yr
# 6649   Junior high school                   Owner          Below 1yr
# 5817   Junior high school                Employee             5-10yr
# 319    Junior high school                Employee             5-10yr
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing is essential for transforming raw data into a format suitable for further analysis and modeling. Follow these steps to ensure your data is ready for predictive modeling or advanced analytics:
# - **Handling Missing Values**: Replace missing values with appropriate statistics (mean, median, mode) or use more complex imputation techniques.
# - **Normalization/Scaling**: Scale data to a small, specified range like 0 to 1, or transform it to have a mean of zero and a standard deviation of one.
# - **Label Encoding**: Convert categorical text data into model-understandable numbers where the labels are ordered.
# - **One-Hot Encoding**: Use for nominal categorical data where no ordinal relationship exists to transform the data into a binary column for each category. (Be careful not to increase the dimensionality significantly)
# - **Detection and Treatment of Outliers**: Use statistical tests, box plots, or scatter plots to identify outliers and then cap, trim, or use robust methods to reduce the effect of outliers, depending on the context.
# - **Feature Engineering**: Enhance your dataset by creating new features and transforming existing ones. This might involve combining data from different columns, applying transformations, or reducing dimensionality with techniques like PCA to improve model performance.
#
# Consider these steps as a foundation, and feel free to introduce additional preprocessing techniques as needed to address specific characteristics of your dataset.

# %%
df['Casualty_class'] = df['Casualty_class'].replace('na', np.nan)
df['Sex_of_casualty'] = df['Sex_of_casualty'].replace('na', np.nan)
df['Age_band_of_casualty'] = df['Age_band_of_casualty'].replace('na', np.nan)
df['Casualty_severity'] = df['Casualty_severity'].replace('na', np.nan)

# %%
mode_educational_level = df['Educational_level'].mode()[0]
df['Educational_level'].fillna(mode_educational_level, inplace=True)

mode_Vehicle_driver_relation = df['Vehicle_driver_relation'].mode()[0]
df['Vehicle_driver_relation'].fillna(mode_Vehicle_driver_relation, inplace=True)

mode_Driving_experience = df['Driving_experience'].mode()[0]
df['Driving_experience'].fillna(mode_Driving_experience, inplace=True)

mode_Type_of_vehicle = df['Type_of_vehicle'].mode()[0]
df['Type_of_vehicle'].fillna(mode_Type_of_vehicle, inplace=True)

mode_Owner_of_vehicle = df['Owner_of_vehicle'].mode()[0]
df['Owner_of_vehicle'].fillna(mode_Owner_of_vehicle, inplace=True)

mode_Area_accident_occured = df['Area_accident_occured'].mode()[0]
df['Area_accident_occured'].fillna(mode_Area_accident_occured, inplace=True)

mode_Lanes_or_Medians = df['Lanes_or_Medians'].mode()[0]
df['Lanes_or_Medians'].fillna(mode_Lanes_or_Medians, inplace=True)

mode_Road_allignment = df['Road_allignment'].mode()[0]
df['Road_allignment'].fillna(mode_Road_allignment, inplace=True)

mode_Types_of_Junction = df['Types_of_Junction'].mode()[0]
df['Types_of_Junction'].fillna(mode_Types_of_Junction, inplace=True)


mode_Road_surface_type = df['Road_surface_type'].mode()[0]
df['Road_surface_type'].fillna(mode_Road_surface_type, inplace=True)


mode_Type_of_collision = df['Type_of_collision'].mode()[0]
df['Type_of_collision'].fillna(mode_Type_of_collision, inplace=True)


mode_Vehicle_movement = df['Vehicle_movement'].mode()[0]
df['Vehicle_movement'].fillna(mode_Vehicle_movement, inplace=True)




mode_Casualty_class = df['Casualty_class'].mode()[0]
df['Casualty_class'].fillna(mode_Casualty_class, inplace=True)


mode_Sex_of_casualty = df['Sex_of_casualty'].mode()[0]
df['Sex_of_casualty'].fillna(mode_Sex_of_casualty, inplace=True)


mode_Age_band_of_casualty = df['Age_band_of_casualty'].mode()[0]
df['Age_band_of_casualty'].fillna(mode_Age_band_of_casualty, inplace=True)


mode_Casualty_severity = df['Casualty_severity'].mode()[0]
df['Casualty_severity'].fillna(mode_Casualty_severity, inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction                 0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
df['Time'] = df['Time'].dt.strftime('%H:%M')
# Out:
# <ipython-input-234-689b40db73a3>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df.sample(10)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 9119   12:00    Saturday            Over 51          Male  Junior high school
# 11485  16:55      Friday            Unknown          Male  Junior high school
# 6717   21:10      Friday            Unknown        Female  Junior high school
# 5991   21:30      Monday           Under 18          Male  Junior high school
# 5187   20:52     Tuesday              18-30          Male  Junior high school
# 5106   12:04      Monday              31-50          Male   Elementary school
# 1211   09:25   Wednesday              31-50          Male  Junior high school
# 7072   16:07     Tuesday              31-50          Male         High school
# 11151  17:55    Saturday              18-30          Male  Junior high school
# 6453   19:50    Thursday              18-30          Male   Elementary school
#
#       Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

scale = ['Number_of_vehicles_involved', 'Number_of_casualties']
df[scale] = min_max_scaler.fit_transform(df[scale])

# %%
df.head()
# Out:
#     Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02      Monday              18-30          Male   Above high school
# 1  17:02      Monday              31-50          Male  Junior high school
# 2  17:02      Monday              18-30          Male  Junior high school
# 3  01:06      Sunday              18-30          Male  Junior high school
# 4  01:06      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr           Automobile
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
print(df['Educational_level'])
print(df['Driving_experience'])
print(df['Age_band_of_driver'])
# Out:
# 0         Above high school
# 1        Junior high school
# 2        Junior high school
# 3        Junior high school
# 4        Junior high school
#                 ...
# 12311    Junior high school
# 12312     Elementary school
# 12313    Junior high school
# 12314    Junior high school
# 12315    Junior high school
# Name: Educational_level, Length: 12316, dtype: object
# 0             1-2yr
# 1        Above 10yr
# 2             1-2yr
# 3            5-10yr
# 4             2-5yr
#             ...
# 12311         2-5yr
# 12312        5-10yr
# 12313        5-10yr
# 12314    Above 10yr
# 12315        5-10yr
# Name: Driving_experience, Length: 12316, dtype: object
# 0          18-30
# 1          31-50
# 2          18-30
# 3          18-30
# 4          18-30
#           ...
# 12311      31-50
# 12312    Unknown
# 12313    Over 51
# 12314      18-30
# 12315      18-30
# Name: Age_band_of_driver, Length: 12316, dtype: object

# %%
unique_educational_level = df['Educational_level'].unique()
unique_driving_experience = df['Driving_experience'].unique()
unique_age_band_of_driver = df['Age_band_of_driver'].unique()

unique_educational_level, unique_driving_experience, unique_age_band_of_driver
# Out:
# (array(['Above high school', 'Junior high school', 'Elementary school',
#         'High school', 'Unknown', 'Illiterate', 'Writing & reading'],
#        dtype=object),
#  array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', 'No Licence',
#         'Below 1yr', 'unknown'], dtype=object),
#  array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object))

# %% [markdown]
# ## Data Visualization
# Create various plots to visualize the relationships in the data. Consider using the following to show different aspects of the data:
#
# * Heatmap of Correlation Matrix.
# * Line plots.
# * Scatter plots.
# * Histograms.
# * Boxplots.
#
# Use more if needed!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      0.173446              0.078307
# std                       0.114798              0.143883
# min                       0.000000              0.000000
# 25%                       0.166667              0.000000
# 50%                       0.166667              0.000000
# 75%                       0.166667              0.142857
# max                       1.000000              1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

age_mapping = {'18-30': 24, '31-50': 40.5, 'Over 51': 60, 'Under 18': 15}
df['Age_band_of_driver_numeric'] = df['Age_band_of_driver'].map(age_mapping)

df.head(10)
# Out:
#     Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02      Monday              18-30          Male   Above high school
# 1  17:02      Monday              31-50          Male  Junior high school
# 2  17:02      Monday              18-30          Male  Junior high school
# 3  01:06      Sunday              18-30          Male  Junior high school
# 4  01:06      Sunday              18-30          Male  Junior high school
# 5  14:15      Friday              31-50          Male  Junior high school
# 6  17:30   Wednesday              18-30          Male  Junior high school
# 7  17:20      Friday              18-30          Male  Junior high school
# 8  17:20      Friday              18-30          Male  Junior high school
# 9  17:20      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# ...

# %%
corr_matrix = df.select_dtypes(include=['number']).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Time', y='Number_of_vehicles_involved', data=df)
plt.title('Number of Vehicles Involved Over Time')
plt.xlabel('Time')
plt.ylabel('Number of Vehicles Involved')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Number_of_vehicles_involved', y='Number_of_casualties', data=df)
plt.title('Number of Vehicles Involved vs Number of Casualties')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Number of Casualties')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Number_of_vehicles_involved'], bins=10, kde=True)
plt.title('Histogram of Number of Vehicles Involved')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Number_of_casualties', data=df)
plt.title('Boxplot of Number of Casualties')
plt.xlabel('Number of Casualties')
plt.show()

# %%
age_counts = df['Age_band_of_driver'].value_counts()

plt.figure(figsize=(10, 6))
age_counts.plot(kind='bar')
plt.title('Distribution of Age Band of Drivers')
plt.xlabel('Age Band')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
grouped_data = df.groupby(['Day_of_week', 'Area_accident_occured']).size().unstack().fillna(0)

#heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(grouped_data, annot=True, cmap='YlGnBu', fmt='g')
plt.title('Accident Frequency by Day of Week and Area')
plt.xlabel('Area of Accident')
plt.ylabel('Day of Week')
plt.show()

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]


df = remove_outliers(df, "Number_of_casualties")
df = remove_outliers(df, "Number_of_vehicles_involved")

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# #The heatmap showed us the correlation between all the numerical variables that is in the dataset
#
# #The line plot showed us the number of vehicles involved Over time
#
# #The scatter plot showed the relationship between the number of vehicles and casualties
#
# #The histogram Showed the distribution of the number of vehicles
#
# #The boxplot showed the outliers

# %% [markdown]
# ## Feature Selection
# - Choose features that you believe will most influence the outcome based on your analysis and the insights from your visualizations. Focus on those that appear most impactful to include in your modeling.
#
# ## Train-Test Split
# * Divide the dataset into training and testing sets to evaluate the performance of your models.

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import accuracy_score


selected_columns = ['Day_of_week', 'Sex_of_driver']
target_column = 'Accident_severity'


X = df[selected_columns]
y = df[target_column]


encoder = OneHotEncoder(sparse=False)
X_encoded = encoder.fit_transform(X)


y_encoder = LabelEncoder()
y_encoded = y_encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Modeling
#
# Once the data is split into training and testing sets, the next step is to build models to make predictions. Here, we will explore several machine learning algorithms, each with its unique characteristics and suitability for different types of data and problems. You will implement the following models:
#
# ### 1. Logistic Regression
#
# ### 2. Decision Tree Classifier
#
# ### 3. Support Vector Machine (SVM)
#
# ### 4. K-Neighbors Classifier
#
# ### Implementing the Models
# - For each model, use the training data you have prepared to train the model.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()

log_reg.fit(X_train_encoded, y_train_encoded)


y_pred_log_reg = log_reg.predict(X_test_encoded)


accuracy_log_reg = accuracy_score(y_test_encoded, y_pred_log_reg)
print(f'Logistic Regression Accuracy: {accuracy_log_reg}')
# Out:
# Logistic Regression Accuracy: 0.8833403273185061

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(random_state=42)
tree_clf.fit(X_train_encoded, y_train_encoded)
y_pred_tree = tree_clf.predict(X_test_encoded)

accuracy_tree = accuracy_score(y_test_encoded, y_pred_tree)
print(f'Decision Tree Classifier Accuracy: {accuracy_tree}')
# Out:
# Decision Tree Classifier Accuracy: 0.8833403273185061

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(X_train_encoded, y_train_encoded)
y_pred_svm = svm_model.predict(X_test_encoded)

accuracy_svm = accuracy_score(y_test_encoded, y_pred_svm)
print(f'SVM Model Accuracy: {accuracy_svm}')
# Out:
# SVM Model Accuracy: 0.8833403273185061

# %% [markdown]
# #### K-Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train_encoded, y_train_encoded)

y_pred_knn = knn_model.predict(X_test_encoded)

accuracy_knn = accuracy_score(y_test_encoded, y_pred_knn)
print(f'K-Nearest Neighbors Accuracy: {accuracy_knn}')
# Out:
# K-Nearest Neighbors Accuracy: 0.8833403273185061

# %% [markdown]
# ## Model Evaluation
#
# After training your models, it's crucial to evaluate their performance to understand their effectiveness and limitations. This section outlines various techniques and metrics to assess the performance of each model you have implemented.
#
# ### Evaluation Techniques
# 1. **Confusion Matrix**
#
# 2. **Accuracy**
#
# 3. **Precision and Recall**
#
# 4. **F1 Score**
#
# 5. **ROC Curve and AUC**
#
# ### Implementing Evaluation
# - Calculate the metrics listed above using your test data.

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def evaluate_f1_score(y_test, y_pred, model_name="Model"):

    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'{model_name} F1 Score: {f1}')

log_reg_pred = log_reg.predict(X_test_encoded)
evaluate_f1_score(y_test_encoded, log_reg_pred, model_name="Logistic Regression")

tree_pred = tree_clf.predict(X_test_encoded)
evaluate_f1_score(y_test_encoded, tree_pred, model_name="Decision Tree")

svm_pred = svm_model.predict(X_test_encoded)
evaluate_f1_score(y_test_encoded, svm_pred, model_name="SVM")

knn_pred = knn_model.predict(X_test_encoded)
evaluate_f1_score(y_test_encoded, knn_pred, model_name="K-Neighbors Classifier")
# Out:
# Logistic Regression F1 Score: 0.8286236136387948
# Decision Tree F1 Score: 0.8286236136387948
# SVM F1 Score: 0.8286236136387948
# K-Neighbors Classifier F1 Score: 0.8286236136387948

# %% [markdown]
# ## Project Questions:
#
# ### Comparative Analysis
#
# - **Compare Metrics**: Examine the performance metrics (such as accuracy, precision, and recall) of each model. Document your observations on which model performs best for your dataset and the problem you're addressing.
# - **Evaluate Trade-offs**: Discuss the trade-offs you encountered when choosing between models. Consider factors like computational efficiency, ease of implementation, and model interpretability.
# - **Justify Your Choice**: After comparing and evaluating, explain why you believe one model is the best choice. Provide a clear rationale based on the performance metrics and trade-offs discussed.
# - **Feature Importance**: Identify and discuss the most important features for the best-performing model. How do these features impact the predictions? Use the visualizations you have created to justify your answer if necessary.
# - **Model Limitations**: Discuss any limitations you encountered with the models you used. Are there any aspects of the data or the problem that these models do not handle well?
# - **Future Improvements**: Suggest potential improvements or further steps you could take to enhance model performance. This could include trying different algorithms, feature engineering techniques, or tuning hyperparameters.

# %% [markdown]
# ### Answer Here:

# %% [markdown]
# Compare metrics : i only did the f1 score and i get the same results
#
# for all the models i got the same results
